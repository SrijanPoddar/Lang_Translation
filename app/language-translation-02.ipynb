# %%
# !pip3 install indic-nlp-library
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch
import torch.nn.functional as F
from indicnlp.tokenize import indic_tokenize

# %%
data = pd.read_csv("/kaggle/input/sample-data-01/Sentence pairs in English-Hindi - 2025-02-11.tsv",sep="\t",header=None, names = ["SrcSentID","SrcSent","DstSentID","DstSent"])
data.head()
# Out:
#    SrcSentID                                  SrcSent  DstSentID  \
# 0       1282                       Muiriel is 20 now.     485968
# 1       1282                       Muiriel is 20 now.    2060319
# 2       1294  Education in this world disappoints me.     485564
# 3       1302                       That won't happen.    2060320
# 4       1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.shape
# Out:
# (13182, 4)

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer = AutoTokenizer.from_pretrained("google-T5/T5-base")

# %%
data["SrcSent"]=data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))
# sub-word tokenization ALgorithm used - BPE Byte pair encoding and the one not used is WPT - word piece tokenizer

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"]=data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
data["SrcSent"]=data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
vs=src_sent_tokenizer.get_vocab()
len(vs)
# Out:
# 32100

# %%
hindi_vocab=set()
for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)
len(hindi_vocab)
# Out:
# 7069

# %%
vd = dict()
for idx,token in enumerate(hindi_vocab):
    vd[token] = idx + 3
vd["<SOS>"]=1
vd["<PAD>"]=0
vd["<EOS>"]=2

# %%
hindi_idx2vocab = dict(zip(vd.values(),vd.keys()))

# %% [markdown]
# Types of token used in every model <br>
# "SOS" - Start of sentence (1) <br>
# "PAD" - Padding (0)<br>
# "EOS" - End of sentence (2)<br>
# Gradient descent algorithm in the case of neural network is called backpropogation algorithm to reduce the loss of data <br>

# %%
def covert_hindi_token_to_ids(hindi_sent):
    return [vd[token] for token in hindi_sent]

# %%
data["DstSent"]=data["DstSent"].apply(lambda x:covert_hindi_token_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [4702, 5336, 6609, 5180, 5410, 3029, 3372, 658...
# 1         [4702, 5336, 6609, 5180, 5410, 6580, 2855]
# 2  [2693, 2139, 664, 1467, 1592, 1729, 4434, 2519...
# 3                            [4972, 1277, 482, 2855]
# 4            [5804, 6958, 4083, 597, 34, 6580, 2855]

# %%
def insert_sos_token_id(hindi_token_sent_ids):
    return [1]+hindi_token_sent_ids

# %%
data["DstSentInput"]=data["DstSent"].apply(lambda x:insert_sos_token_id(x))
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [4702, 5336, 6609, 5180, 5410, 3029, 3372, 658...
# 1         [4702, 5336, 6609, 5180, 5410, 6580, 2855]
# 2  [2693, 2139, 664, 1467, 1592, 1729, 4434, 2519...
# 3                            [4972, 1277, 482, 2855]
# 4            [5804, 6958, 4083, 597, 34, 6580, 2855]
#
#                                         DstSentInput
# 0  [1, 4702, 5336, 6609, 5180, 5410, 3029, 3372, ...
# 1      [1, 4702, 5336, 6609, 5180, 5410, 6580, 2855]
# 2  [1, 2693, 2139, 664, 1467, 1592, 1729, 4434, 2...
# 3                         [1, 4972, 1277, 482, 2855]
# 4         [1, 5804, 6958, 4083, 597, 34, 6580, 2855]

# %%
def insert_eos_token_id(hindi_token_sent_ids):
    return hindi_token_sent_ids+[2]

# %%
data["DstSentLabel"]=data["DstSent"].apply(lambda x:insert_eos_token_id(x))
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [4702, 5336, 6609, 5180, 5410, 3029, 3372, 658...
# 1         [4702, 5336, 6609, 5180, 5410, 6580, 2855]
# 2  [2693, 2139, 664, 1467, 1592, 1729, 4434, 2519...
# 3                            [4972, 1277, 482, 2855]
# 4            [5804, 6958, 4083, 597, 34, 6580, 2855]
#
#                                         DstSentInput  \
# 0  [1, 4702, 5336, 6609, 5180, 5410, 3029, 3372, ...
# 1      [1, 4702, 5336, 6609, 5180, 5410, 6580, 2855]
# 2  [1, 2693, 2139, 664, 1467, 1592, 1729, 4434, 2...
# 3                         [1, 4972, 1277, 482, 2855]
# 4         [1, 5804, 6958, 4083, 597, 34, 6580, 2855]
#
#                                         DstSentLabel
# 0  [4702, 5336, 6609, 5180, 5410, 3029, 3372, 658...
# 1      [4702, 5336, 6609, 5180, 5410, 6580, 2855, 2]
# 2  [2693, 2139, 664, 1467, 1592, 1729, 4434, 2519...
# 3                         [4972, 1277, 482, 2855, 2]
# 4         [5804, 6958, 4083, 597, 34, 6580, 2855, 2]

# %%
data.columns
# Out:
# Index(['SrcSent', 'DstSent', 'DstSentInput', 'DstSentLabel'], dtype='object')

# %%
X = list(data["SrcSent"])
Y_input = list(data["DstSentInput"])
Y_label = list(data["DstSentLabel"])

# %%
X_tensor = [torch.tensor(tokenized_eng_sent_ids) for tokenized_eng_sent_ids in X]
Y_input_tensor = [torch.tensor(tokenized_hindi_sent_ids) for tokenized_hindi_sent_ids in Y_input]
Y_label_tensor = [torch.tensor(tokenized_hindi_sent_ids) for tokenized_hindi_sent_ids in Y_label]

# %%
X_padded = torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first = True)
Y_padded_input = torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first = True)
Y_padded_label = torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first = True)

# %%
ns=X_padded.shape[1]
ns
# Out:
# 68

# %%
nd=Y_padded_label.shape[1]
nd
# Out:
# 68

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=src_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)

    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out = self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)

        return encoder_output, (final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):

    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()

        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=dst_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)
        self.prediction_layer = torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        #self.prediction_layer_activation = torch.nn.Softmax(dim=2)

    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):
        
        first_embedding_layer_out = self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out, final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                         (final_encoder_output,
                                                                                                          final_cell_state))
        prediction = self.prediction_layer(decoder_lstm_layer_out)
        
        return prediction, (final_decoder_lstm_layer_out, final_cell_state)

# %%
class Seq2SeqEncDec(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,dst_lang_vocab_size,word_embedding_dim):
        super(Seq2SeqEncDec,self).__init__()

        self.encoder = Encoder(src_lang_vocab_size,word_embedding_dim)
        self.decoder = Decoder(dst_lang_vocab_size,word_embedding_dim)

    def forward(self,X_padded_mini_batch,Y_padded_input_mini_batch):

        encoder_output, (final_encoder_output,final_cell_state) = self.encoder(X_padded_mini_batch)
        y_hat_mini_batch = self.decoder(Y_padded_input_mini_batch,
                                        final_encoder_output,final_cell_state)

        return y_hat_mini_batch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cuda

# %%
X_padded_train = X_padded[0:13000]
Y_padded_input_train = Y_padded_input[0:13000]
Y_padded_label_train = Y_padded_label[0:13000]

X_padded_test = X_padded[13000:]
Y_padded_input_test = Y_padded_input[13000:]
Y_padded_label_test = Y_padded_label[13000:]

# %%
network = Seq2SeqEncDec(len(vs),len(vd),128).to(device)

# %%
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(network.parameters())
num_epochs = 300
mb_size = 65

for epoch in range(num_epochs):
    for i in range(X_padded_train.shape[0]//mb_size):

        X_train_mb = X_padded_train[i*mb_size:(i+1)*mb_size]
        Y_input_mb = Y_padded_input_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_padded_label_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_label_mb.reshape(Y_label_mb.shape[0]*Y_label_mb.shape[1],)
        
        X_train_mb, Y_input_mb, Y_label_mb = X_train_mb.to(device), Y_input_mb.to(device), Y_label_mb.to(device)

        y_hat_train_mb = network(X_train_mb,Y_input_mb)
        y_hat_train_mb = y_hat_train_mb[0]
        y_hat_train_mb = y_hat_train_mb.reshape(y_hat_train_mb.shape[0]*y_hat_train_mb.shape[1],
                                                y_hat_train_mb.shape[2])

        loss_fn_value = loss_fn(y_hat_train_mb,Y_label_mb)

        loss_fn_value.backward()
        #torch.nn.utils.clip_grad_norm_(network.parameters(),max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        print("Epoch # {}, Time Step # {}, Loss Value = {}".format(epoch,i,loss_fn_value))
# Out:
# Epoch # 0, Time Step # 0, Loss Value = 8.873336791992188
# Epoch # 0, Time Step # 1, Loss Value = 8.844696998596191
# Epoch # 0, Time Step # 2, Loss Value = 8.812073707580566
# Epoch # 0, Time Step # 3, Loss Value = 8.792744636535645
# Epoch # 0, Time Step # 4, Loss Value = 8.76591968536377
# Epoch # 0, Time Step # 5, Loss Value = 8.743067741394043
# Epoch # 0, Time Step # 6, Loss Value = 8.725313186645508
# Epoch # 0, Time Step # 7, Loss Value = 8.667067527770996
# Epoch # 0, Time Step # 8, Loss Value = 8.639947891235352
# Epoch # 0, Time Step # 9, Loss Value = 8.5847749710083
# Epoch # 0, Time Step # 10, Loss Value = 8.533122062683105
# Epoch # 0, Time Step # 11, Loss Value = 8.469985961914062
# Epoch # 0, Time Step # 12, Loss Value = 8.331007957458496
# Epoch # 0, Time Step # 13, Loss Value = 8.350089073181152
# Epoch # 0, Time Step # 14, Loss Value = 8.181182861328125
# Epoch # 0, Time Step # 15, Loss Value = 8.090423583984375
# Epoch # 0, Time Step # 16, Loss Value = 7.936682224273682
# Epoch # 0, Time Step # 17, Loss Value = 7.784838676452637
# Epoch # 0, Time Step # 18, Loss Value = 7.522108554840088
# Epoch # 0, Time Step # 19, Loss Value = 7.479481220245361
# Epoch # 0, Time Step # 20, Loss Value = 7.319869518280029
# Epoch # 0, Time Step # 21, Loss Value = 7.0911149978637695
# Epoch # 0, Time Step # 22, Loss Value = 6.915238857269287
# Epoch # 0, Time Step # 23, Loss Value = 6.74538516998291
# Epoch # 0, Time Step # 24, Loss Value = 6.727883815765381
# Epoch # 0, Time Step # 25, Loss Value = 6.5633955001831055
# Epoch # 0, Time Step # 26, Loss Value = 6.36733865737915
# Epoch # 0, Time Step # 27, Loss Value = 6.28691291809082
# Epoch # 0, Time Step # 28, Loss Value = 6.084892749786377
# Epoch # 0, Time Step # 29, Loss Value = 5.993580341339111
# Epoch # 0, Time Step # 30, Loss Value = 5.824721336364746
# Epoch # 0, Time Step # 31, Loss Value = 5.759466648101807
# Epoch # 0, Time Step # 32, Loss Value = 5.645411968231201
# Epoch # 0, Time Step # 33, Loss Value = 5.580053806304932
# Epoch # 0, Time Step # 34, Loss Value = 5.883089065551758
# Epoch # 0, Time Step # 35, Loss Value = 6.08123254776001
# Epoch # 0, Time Step # 36, Loss Value = 6.100490093231201
# Epoch # 0, Time Step # 37, Loss Value = 5.923126697540283
# Epoch # 0, Time Step # 38, Loss Value = 6.0065107345581055
# Epoch # 0, Time Step # 39, Loss Value = 5.942081928253174
# Epoch # 0, Time Step # 40, Loss Value = 5.6309494972229
# Epoch # 0, Time Step # 41, Loss Value = 5.838738441467285
# Epoch # 0, Time Step # 42, Loss Value = 5.469840049743652
# Epoch # 0, Time Step # 43, Loss Value = 5.746599197387695
# Epoch # 0, Time Step # 44, Loss Value = 5.50302791595459
# Epoch # 0, Time Step # 45, Loss Value = 5.516524791717529
# Epoch # 0, Time Step # 46, Loss Value = 5.783172130584717
# Epoch # 0, Time Step # 47, Loss Value = 5.431506633758545
# Epoch # 0, Time Step # 48, Loss Value = 5.647532939910889
# Epoch # 0, Time Step # 49, Loss Value = 5.446018218994141
# Epoch # 0, Time Step # 50, Loss Value = 5.461160182952881
# Epoch # 0, Time Step # 51, Loss Value = 5.633009910583496
# Epoch # 0, Time Step # 52, Loss Value = 5.747636795043945
# Epoch # 0, Time Step # 53, Loss Value = 5.615616321563721
# Epoch # 0, Time Step # 54, Loss Value = 5.81859827041626
# Epoch # 0, Time Step # 55, Loss Value = 6.009042739868164
# Epoch # 0, Time Step # 56, Loss Value = 5.454721450805664
# Epoch # 0, Time Step # 57, Loss Value = 5.653126239776611
# Epoch # 0, Time Step # 58, Loss Value = 5.681463718414307
# Epoch # 0, Time Step # 59, Loss Value = 5.139382362365723
# Epoch # 0, Time Step # 60, Loss Value = 5.217315196990967
# Epoch # 0, Time Step # 61, Loss Value = 5.2851738929748535
# Epoch # 0, Time Step # 62, Loss Value = 5.807239532470703
# Epoch # 0, Time Step # 63, Loss Value = 5.985811710357666
# Epoch # 0, Time Step # 64, Loss Value = 5.482283592224121
# Epoch # 0, Time Step # 65, Loss Value = 5.665802478790283
# Epoch # 0, Time Step # 66, Loss Value = 6.081090927124023
# Epoch # 0, Time Step # 67, Loss Value = 6.227534770965576
# Epoch # 0, Time Step # 68, Loss Value = 5.666369915008545
# Epoch # 0, Time Step # 69, Loss Value = 6.207174777984619
# Epoch # 0, Time Step # 70, Loss Value = 5.637578964233398
# Epoch # 0, Time Step # 71, Loss Value = 5.80561637878418
# Epoch # 0, Time Step # 72, Loss Value = 5.591404438018799
# Epoch # 0, Time Step # 73, Loss Value = 5.949260711669922
# Epoch # 0, Time Step # 74, Loss Value = 5.666071891784668
# Epoch # 0, Time Step # 75, Loss Value = 5.640291690826416
# Epoch # 0, Time Step # 76, Loss Value = 5.782828330993652
# Epoch # 0, Time Step # 77, Loss Value = 5.632325649261475
# Epoch # 0, Time Step # 78, Loss Value = 5.316670894622803
# Epoch # 0, Time Step # 79, Loss Value = 5.679711818695068
# Epoch # 0, Time Step # 80, Loss Value = 4.993009090423584
# Epoch # 0, Time Step # 81, Loss Value = 5.367184162139893
# Epoch # 0, Time Step # 82, Loss Value = 4.974704742431641
# Epoch # 0, Time Step # 83, Loss Value = 5.218418598175049
# Epoch # 0, Time Step # 84, Loss Value = 5.09891414642334
# Epoch # 0, Time Step # 85, Loss Value = 4.899069309234619
# Epoch # 0, Time Step # 86, Loss Value = 4.727528095245361
# Epoch # 0, Time Step # 87, Loss Value = 4.771444320678711
# Epoch # 0, Time Step # 88, Loss Value = 4.9702067375183105
# Epoch # 0, Time Step # 89, Loss Value = 4.903378963470459
# Epoch # 0, Time Step # 90, Loss Value = 4.271688938140869
# Epoch # 0, Time Step # 91, Loss Value = 4.602610111236572
# Epoch # 0, Time Step # 92, Loss Value = 5.476562023162842
# Epoch # 0, Time Step # 93, Loss Value = 4.425206661224365
# Epoch # 0, Time Step # 94, Loss Value = 5.455604076385498
# Epoch # 0, Time Step # 95, Loss Value = 6.572935581207275
# Epoch # 0, Time Step # 96, Loss Value = 6.647092819213867
# Epoch # 0, Time Step # 97, Loss Value = 5.436526298522949
# Epoch # 0, Time Step # 98, Loss Value = 4.826923847198486
# Epoch # 0, Time Step # 99, Loss Value = 5.016280174255371
# Epoch # 0, Time Step # 100, Loss Value = 5.121277809143066
# Epoch # 0, Time Step # 101, Loss Value = 4.432291030883789
# Epoch # 0, Time Step # 102, Loss Value = 4.323974609375
# Epoch # 0, Time Step # 103, Loss Value = 4.835093975067139
# Epoch # 0, Time Step # 104, Loss Value = 4.808256149291992
# Epoch # 0, Time Step # 105, Loss Value = 4.688534736633301
# Epoch # 0, Time Step # 106, Loss Value = 4.647436141967773
# Epoch # 0, Time Step # 107, Loss Value = 4.301599025726318
# Epoch # 0, Time Step # 108, Loss Value = 4.569943428039551
# Epoch # 0, Time Step # 109, Loss Value = 4.318731307983398
# Epoch # 0, Time Step # 110, Loss Value = 4.518601417541504
# Epoch # 0, Time Step # 111, Loss Value = 5.639529705047607
# Epoch # 0, Time Step # 112, Loss Value = 6.106433868408203
# Epoch # 0, Time Step # 113, Loss Value = 5.522063255310059
# Epoch # 0, Time Step # 114, Loss Value = 4.99153995513916
# Epoch # 0, Time Step # 115, Loss Value = 4.995693683624268
# Epoch # 0, Time Step # 116, Loss Value = 5.206631183624268
# Epoch # 0, Time Step # 117, Loss Value = 5.009404182434082
# Epoch # 0, Time Step # 118, Loss Value = 4.709320545196533
# Epoch # 0, Time Step # 119, Loss Value = 5.241912364959717
# Epoch # 0, Time Step # 120, Loss Value = 5.5865302085876465
# Epoch # 0, Time Step # 121, Loss Value = 4.528117656707764
# Epoch # 0, Time Step # 122, Loss Value = 4.837986946105957
# Epoch # 0, Time Step # 123, Loss Value = 4.773171901702881
# Epoch # 0, Time Step # 124, Loss Value = 4.632913589477539
# Epoch # 0, Time Step # 125, Loss Value = 4.799510478973389
# Epoch # 0, Time Step # 126, Loss Value = 4.745638370513916
# Epoch # 0, Time Step # 127, Loss Value = 4.894499778747559
# Epoch # 0, Time Step # 128, Loss Value = 5.380144119262695
# Epoch # 0, Time Step # 129, Loss Value = 5.523925304412842
# Epoch # 0, Time Step # 130, Loss Value = 5.461999893188477
# Epoch # 0, Time Step # 131, Loss Value = 4.902040958404541
# Epoch # 0, Time Step # 132, Loss Value = 4.517369270324707
# Epoch # 0, Time Step # 133, Loss Value = 4.307910442352295
# Epoch # 0, Time Step # 134, Loss Value = 4.867271900177002
# Epoch # 0, Time Step # 135, Loss Value = 4.583202362060547
# Epoch # 0, Time Step # 136, Loss Value = 4.74899435043335
# Epoch # 0, Time Step # 137, Loss Value = 4.952381134033203
# Epoch # 0, Time Step # 138, Loss Value = 4.497974872589111
# Epoch # 0, Time Step # 139, Loss Value = 5.141107559204102
# Epoch # 0, Time Step # 140, Loss Value = 4.83711051940918
# Epoch # 0, Time Step # 141, Loss Value = 4.596678733825684
# Epoch # 0, Time Step # 142, Loss Value = 4.403712272644043
# Epoch # 0, Time Step # 143, Loss Value = 4.704894065856934
# Epoch # 0, Time Step # 144, Loss Value = 4.381510257720947
# Epoch # 0, Time Step # 145, Loss Value = 4.371294975280762
# Epoch # 0, Time Step # 146, Loss Value = 4.261244773864746
# Epoch # 0, Time Step # 147, Loss Value = 5.012489318847656
# Epoch # 0, Time Step # 148, Loss Value = 4.615576267242432
# Epoch # 0, Time Step # 149, Loss Value = 4.833722114562988
# Epoch # 0, Time Step # 150, Loss Value = 4.577352046966553
# Epoch # 0, Time Step # 151, Loss Value = 4.76997709274292
# Epoch # 0, Time Step # 152, Loss Value = 4.872734069824219
# Epoch # 0, Time Step # 153, Loss Value = 4.5695390701293945
# Epoch # 0, Time Step # 154, Loss Value = 4.480412483215332
# Epoch # 0, Time Step # 155, Loss Value = 4.692705154418945
# Epoch # 0, Time Step # 156, Loss Value = 4.772645473480225
# Epoch # 0, Time Step # 157, Loss Value = 4.656912326812744
# Epoch # 0, Time Step # 158, Loss Value = 4.641813278198242
# Epoch # 0, Time Step # 159, Loss Value = 5.596288681030273
# Epoch # 0, Time Step # 160, Loss Value = 5.334243297576904
# Epoch # 0, Time Step # 161, Loss Value = 5.694735050201416
# Epoch # 0, Time Step # 162, Loss Value = 5.593677043914795
# Epoch # 0, Time Step # 163, Loss Value = 5.1018476486206055
# Epoch # 0, Time Step # 164, Loss Value = 5.163339614868164
# Epoch # 0, Time Step # 165, Loss Value = 4.935424327850342
# Epoch # 0, Time Step # 166, Loss Value = 4.7964091300964355
# Epoch # 0, Time Step # 167, Loss Value = 5.268764495849609
# Epoch # 0, Time Step # 168, Loss Value = 4.948697566986084
# Epoch # 0, Time Step # 169, Loss Value = 5.106235027313232
# Epoch # 0, Time Step # 170, Loss Value = 5.161932945251465
# Epoch # 0, Time Step # 171, Loss Value = 5.243703842163086
# Epoch # 0, Time Step # 172, Loss Value = 5.5751471519470215
# Epoch # 0, Time Step # 173, Loss Value = 5.275625705718994
# Epoch # 0, Time Step # 174, Loss Value = 5.392154693603516
# Epoch # 0, Time Step # 175, Loss Value = 4.879913806915283
# Epoch # 0, Time Step # 176, Loss Value = 4.751581192016602
# Epoch # 0, Time Step # 177, Loss Value = 4.8046183586120605
# Epoch # 0, Time Step # 178, Loss Value = 5.148707389831543
# Epoch # 0, Time Step # 179, Loss Value = 4.978261470794678
# Epoch # 0, Time Step # 180, Loss Value = 5.275609016418457
# Epoch # 0, Time Step # 181, Loss Value = 4.933366775512695
# Epoch # 0, Time Step # 182, Loss Value = 4.6444411277771
# Epoch # 0, Time Step # 183, Loss Value = 4.694981575012207
# Epoch # 0, Time Step # 184, Loss Value = 4.771475791931152
# Epoch # 0, Time Step # 185, Loss Value = 4.722346782684326
# Epoch # 0, Time Step # 186, Loss Value = 4.8725056648254395
# Epoch # 0, Time Step # 187, Loss Value = 5.862671375274658
# Epoch # 0, Time Step # 188, Loss Value = 4.735830307006836
# Epoch # 0, Time Step # 189, Loss Value = 4.7699809074401855
# Epoch # 0, Time Step # 190, Loss Value = 4.762299537658691
# Epoch # 0, Time Step # 191, Loss Value = 4.739353179931641
# Epoch # 0, Time Step # 192, Loss Value = 4.917486667633057
# Epoch # 0, Time Step # 193, Loss Value = 4.50449275970459
# Epoch # 0, Time Step # 194, Loss Value = 4.814517021179199
# Epoch # 0, Time Step # 195, Loss Value = 5.001418590545654
# Epoch # 0, Time Step # 196, Loss Value = 5.1800408363342285
# Epoch # 0, Time Step # 197, Loss Value = 4.921506881713867
# Epoch # 0, Time Step # 198, Loss Value = 4.930021286010742
# Epoch # 0, Time Step # 199, Loss Value = 4.915620803833008
# Epoch # 1, Time Step # 0, Loss Value = 4.732378959655762
# Epoch # 1, Time Step # 1, Loss Value = 5.130697727203369
# Epoch # 1, Time Step # 2, Loss Value = 5.072841644287109
# Epoch # 1, Time Step # 3, Loss Value = 5.488893985748291
# Epoch # 1, Time Step # 4, Loss Value = 5.545712947845459
# Epoch # 1, Time Step # 5, Loss Value = 5.187817096710205
# Epoch # 1, Time Step # 6, Loss Value = 5.46358585357666
# Epoch # 1, Time Step # 7, Loss Value = 5.347012996673584
# Epoch # 1, Time Step # 8, Loss Value = 5.47109842300415
# Epoch # 1, Time Step # 9, Loss Value = 5.487963676452637
# Epoch # 1, Time Step # 10, Loss Value = 5.112000465393066
# Epoch # 1, Time Step # 11, Loss Value = 5.421779155731201
# Epoch # 1, Time Step # 12, Loss Value = 5.03689432144165
# Epoch # 1, Time Step # 13, Loss Value = 5.514246463775635
# Epoch # 1, Time Step # 14, Loss Value = 5.374510765075684
# Epoch # 1, Time Step # 15, Loss Value = 5.372655868530273
# Epoch # 1, Time Step # 16, Loss Value = 5.136786460876465
# Epoch # 1, Time Step # 17, Loss Value = 5.28069543838501
# Epoch # 1, Time Step # 18, Loss Value = 5.061972618103027
# Epoch # 1, Time Step # 19, Loss Value = 5.352008819580078
# Epoch # 1, Time Step # 20, Loss Value = 5.2339067459106445
# Epoch # 1, Time Step # 21, Loss Value = 5.037125587463379
# Epoch # 1, Time Step # 22, Loss Value = 4.836110591888428
# Epoch # 1, Time Step # 23, Loss Value = 5.156618595123291
# Epoch # 1, Time Step # 24, Loss Value = 5.452020168304443
# Epoch # 1, Time Step # 25, Loss Value = 5.208961486816406
# Epoch # 1, Time Step # 26, Loss Value = 5.118871212005615
# Epoch # 1, Time Step # 27, Loss Value = 5.247177600860596
# Epoch # 1, Time Step # 28, Loss Value = 5.0242838859558105
# Epoch # 1, Time Step # 29, Loss Value = 5.025071144104004
# Epoch # 1, Time Step # 30, Loss Value = 4.896187782287598
# Epoch # 1, Time Step # 31, Loss Value = 4.889251232147217
# Epoch # 1, Time Step # 32, Loss Value = 4.823726177215576
# Epoch # 1, Time Step # 33, Loss Value = 4.906192779541016
# Epoch # 1, Time Step # 34, Loss Value = 5.184732913970947
# Epoch # 1, Time Step # 35, Loss Value = 5.411604404449463
# Epoch # 1, Time Step # 36, Loss Value = 5.430692195892334
# Epoch # 1, Time Step # 37, Loss Value = 5.341675758361816
# Epoch # 1, Time Step # 38, Loss Value = 5.291596412658691
# Epoch # 1, Time Step # 39, Loss Value = 5.341389179229736
# Epoch # 1, Time Step # 40, Loss Value = 5.109249591827393
# Epoch # 1, Time Step # 41, Loss Value = 5.209078788757324
# Epoch # 1, Time Step # 42, Loss Value = 4.8990302085876465
# Epoch # 1, Time Step # 43, Loss Value = 5.131853103637695
# Epoch # 1, Time Step # 44, Loss Value = 4.903754234313965
# Epoch # 1, Time Step # 45, Loss Value = 4.933305740356445
# Epoch # 1, Time Step # 46, Loss Value = 5.211863040924072
# Epoch # 1, Time Step # 47, Loss Value = 4.841482162475586
# Epoch # 1, Time Step # 48, Loss Value = 5.068504333496094
# Epoch # 1, Time Step # 49, Loss Value = 4.94681978225708
# Epoch # 1, Time Step # 50, Loss Value = 4.882330417633057
# Epoch # 1, Time Step # 51, Loss Value = 5.069331169128418
# Epoch # 1, Time Step # 52, Loss Value = 5.226145267486572
# Epoch # 1, Time Step # 53, Loss Value = 5.058891773223877
# Epoch # 1, Time Step # 54, Loss Value = 5.260681629180908
# Epoch # 1, Time Step # 55, Loss Value = 5.300141334533691
# Epoch # 1, Time Step # 56, Loss Value = 4.821475028991699
# Epoch # 1, Time Step # 57, Loss Value = 5.043692111968994
# Epoch # 1, Time Step # 58, Loss Value = 5.064060688018799
# Epoch # 1, Time Step # 59, Loss Value = 4.556507110595703
# Epoch # 1, Time Step # 60, Loss Value = 4.581833839416504
# Epoch # 1, Time Step # 61, Loss Value = 4.73613166809082
# Epoch # 1, Time Step # 62, Loss Value = 5.233796119689941
# Epoch # 1, Time Step # 63, Loss Value = 5.392085075378418
# Epoch # 1, Time Step # 64, Loss Value = 4.868514537811279
# Epoch # 1, Time Step # 65, Loss Value = 5.1371235847473145
# Epoch # 1, Time Step # 66, Loss Value = 5.3821330070495605
# Epoch # 1, Time Step # 67, Loss Value = 5.5826802253723145
# Epoch # 1, Time Step # 68, Loss Value = 5.0839738845825195
# Epoch # 1, Time Step # 69, Loss Value = 5.638119697570801
# Epoch # 1, Time Step # 70, Loss Value = 5.096651077270508
# Epoch # 1, Time Step # 71, Loss Value = 5.075177192687988
# Epoch # 1, Time Step # 72, Loss Value = 4.87568473815918
# Epoch # 1, Time Step # 73, Loss Value = 5.3768134117126465
# Epoch # 1, Time Step # 74, Loss Value = 5.162525653839111
# Epoch # 1, Time Step # 75, Loss Value = 5.080873966217041
# Epoch # 1, Time Step # 76, Loss Value = 5.211204528808594
# Epoch # 1, Time Step # 77, Loss Value = 5.07974100112915
# Epoch # 1, Time Step # 78, Loss Value = 4.691946506500244
# Epoch # 1, Time Step # 79, Loss Value = 5.1387858390808105
# Epoch # 1, Time Step # 80, Loss Value = 4.408350467681885
# Epoch # 1, Time Step # 81, Loss Value = 4.89959192276001
# Epoch # 1, Time Step # 82, Loss Value = 4.491075038909912
# Epoch # 1, Time Step # 83, Loss Value = 4.733889579772949
# Epoch # 1, Time Step # 84, Loss Value = 4.534116268157959
# Epoch # 1, Time Step # 85, Loss Value = 4.468982696533203
# Epoch # 1, Time Step # 86, Loss Value = 4.161825656890869
# Epoch # 1, Time Step # 87, Loss Value = 4.312098503112793
# Epoch # 1, Time Step # 88, Loss Value = 4.486791133880615
# Epoch # 1, Time Step # 89, Loss Value = 4.41184663772583
# Epoch # 1, Time Step # 90, Loss Value = 3.7354235649108887
# Epoch # 1, Time Step # 91, Loss Value = 4.150466442108154
# Epoch # 1, Time Step # 92, Loss Value = 5.094400882720947
# Epoch # 1, Time Step # 93, Loss Value = 3.9959521293640137
# Epoch # 1, Time Step # 94, Loss Value = 5.0361552238464355
# Epoch # 1, Time Step # 95, Loss Value = 6.209683895111084
# Epoch # 1, Time Step # 96, Loss Value = 6.3536787033081055
# Epoch # 1, Time Step # 97, Loss Value = 5.047243595123291
# Epoch # 1, Time Step # 98, Loss Value = 4.381584167480469
# Epoch # 1, Time Step # 99, Loss Value = 4.594705104827881
# Epoch # 1, Time Step # 100, Loss Value = 4.735662937164307
# Epoch # 1, Time Step # 101, Loss Value = 4.006859302520752
# Epoch # 1, Time Step # 102, Loss Value = 3.9116809368133545
# Epoch # 1, Time Step # 103, Loss Value = 4.45213508605957
# Epoch # 1, Time Step # 104, Loss Value = 4.367502212524414
# Epoch # 1, Time Step # 105, Loss Value = 4.337813377380371
# Epoch # 1, Time Step # 106, Loss Value = 4.286129474639893
# Epoch # 1, Time Step # 107, Loss Value = 3.922987222671509
# Epoch # 1, Time Step # 108, Loss Value = 4.2302045822143555
# Epoch # 1, Time Step # 109, Loss Value = 3.994741916656494
# Epoch # 1, Time Step # 110, Loss Value = 4.142483711242676
# Epoch # 1, Time Step # 111, Loss Value = 5.2246527671813965
# Epoch # 1, Time Step # 112, Loss Value = 5.653424263000488
# Epoch # 1, Time Step # 113, Loss Value = 5.159228801727295
# Epoch # 1, Time Step # 114, Loss Value = 4.601646423339844
# Epoch # 1, Time Step # 115, Loss Value = 4.593674659729004
# Epoch # 1, Time Step # 116, Loss Value = 4.813018798828125
# Epoch # 1, Time Step # 117, Loss Value = 4.553022861480713
# Epoch # 1, Time Step # 118, Loss Value = 4.356778621673584
# Epoch # 1, Time Step # 119, Loss Value = 4.800644874572754
# Epoch # 1, Time Step # 120, Loss Value = 5.238537788391113
# Epoch # 1, Time Step # 121, Loss Value = 4.1646575927734375
# Epoch # 1, Time Step # 122, Loss Value = 4.482095718383789
# Epoch # 1, Time Step # 123, Loss Value = 4.4712653160095215
# Epoch # 1, Time Step # 124, Loss Value = 4.2827301025390625
# Epoch # 1, Time Step # 125, Loss Value = 4.465280055999756
# Epoch # 1, Time Step # 126, Loss Value = 4.3463969230651855
# Epoch # 1, Time Step # 127, Loss Value = 4.502272129058838
# Epoch # 1, Time Step # 128, Loss Value = 4.997325420379639
# Epoch # 1, Time Step # 129, Loss Value = 5.160498142242432
# Epoch # 1, Time Step # 130, Loss Value = 5.091817855834961
# Epoch # 1, Time Step # 131, Loss Value = 4.5195536613464355
# Epoch # 1, Time Step # 132, Loss Value = 4.173795700073242
# Epoch # 1, Time Step # 133, Loss Value = 3.9841418266296387
# Epoch # 1, Time Step # 134, Loss Value = 4.478358745574951
# Epoch # 1, Time Step # 135, Loss Value = 4.19643497467041
# Epoch # 1, Time Step # 136, Loss Value = 4.41571044921875
# Epoch # 1, Time Step # 137, Loss Value = 4.532618045806885
# Epoch # 1, Time Step # 138, Loss Value = 4.144719123840332
# Epoch # 1, Time Step # 139, Loss Value = 4.757701396942139
# Epoch # 1, Time Step # 140, Loss Value = 4.489989757537842
# Epoch # 1, Time Step # 141, Loss Value = 4.238176345825195
# Epoch # 1, Time Step # 142, Loss Value = 4.038912773132324
# Epoch # 1, Time Step # 143, Loss Value = 4.380290985107422
# Epoch # 1, Time Step # 144, Loss Value = 4.063910961151123
# Epoch # 1, Time Step # 145, Loss Value = 4.005568981170654
# Epoch # 1, Time Step # 146, Loss Value = 3.897711992263794
# Epoch # 1, Time Step # 147, Loss Value = 4.474588871002197
# Epoch # 1, Time Step # 148, Loss Value = 4.264853477478027
# Epoch # 1, Time Step # 149, Loss Value = 4.475247859954834
# Epoch # 1, Time Step # 150, Loss Value = 4.269862174987793
# Epoch # 1, Time Step # 151, Loss Value = 4.3387064933776855
# Epoch # 1, Time Step # 152, Loss Value = 4.519035339355469
# Epoch # 1, Time Step # 153, Loss Value = 4.196712970733643
# Epoch # 1, Time Step # 154, Loss Value = 4.1549763679504395
# Epoch # 1, Time Step # 155, Loss Value = 4.389023780822754
# Epoch # 1, Time Step # 156, Loss Value = 4.418943405151367
# Epoch # 1, Time Step # 157, Loss Value = 4.3714752197265625
# Epoch # 1, Time Step # 158, Loss Value = 4.3458075523376465
# Epoch # 1, Time Step # 159, Loss Value = 5.279500484466553
# Epoch # 1, Time Step # 160, Loss Value = 5.010206699371338
# Epoch # 1, Time Step # 161, Loss Value = 5.283243179321289
# Epoch # 1, Time Step # 162, Loss Value = 5.088164806365967
# Epoch # 1, Time Step # 163, Loss Value = 4.819681644439697
# Epoch # 1, Time Step # 164, Loss Value = 4.890139579772949
# Epoch # 1, Time Step # 165, Loss Value = 4.607583045959473
# Epoch # 1, Time Step # 166, Loss Value = 4.385863780975342
# Epoch # 1, Time Step # 167, Loss Value = 4.863739490509033
# Epoch # 1, Time Step # 168, Loss Value = 4.66933536529541
# Epoch # 1, Time Step # 169, Loss Value = 4.699782848358154
# Epoch # 1, Time Step # 170, Loss Value = 4.773274898529053
# Epoch # 1, Time Step # 171, Loss Value = 4.795510768890381
# Epoch # 1, Time Step # 172, Loss Value = 5.196740627288818
# Epoch # 1, Time Step # 173, Loss Value = 4.906790256500244
# Epoch # 1, Time Step # 174, Loss Value = 5.074402809143066
# Epoch # 1, Time Step # 175, Loss Value = 4.4913010597229
# Epoch # 1, Time Step # 176, Loss Value = 4.405914306640625
# Epoch # 1, Time Step # 177, Loss Value = 4.467077255249023
# Epoch # 1, Time Step # 178, Loss Value = 4.7347612380981445
# Epoch # 1, Time Step # 179, Loss Value = 4.527677059173584
# Epoch # 1, Time Step # 180, Loss Value = 4.75215482711792
# Epoch # 1, Time Step # 181, Loss Value = 4.4790263175964355
# Epoch # 1, Time Step # 182, Loss Value = 4.271975994110107
# Epoch # 1, Time Step # 183, Loss Value = 4.38538122177124
# Epoch # 1, Time Step # 184, Loss Value = 4.435598373413086
# Epoch # 1, Time Step # 185, Loss Value = 4.325324058532715
# Epoch # 1, Time Step # 186, Loss Value = 4.509195327758789
# Epoch # 1, Time Step # 187, Loss Value = 5.561410427093506
# Epoch # 1, Time Step # 188, Loss Value = 4.430508136749268
# Epoch # 1, Time Step # 189, Loss Value = 4.470570087432861
# Epoch # 1, Time Step # 190, Loss Value = 4.410393238067627
# Epoch # 1, Time Step # 191, Loss Value = 4.4324164390563965
# Epoch # 1, Time Step # 192, Loss Value = 4.554841041564941
# Epoch # 1, Time Step # 193, Loss Value = 4.147372245788574
# Epoch # 1, Time Step # 194, Loss Value = 4.43430757522583
# Epoch # 1, Time Step # 195, Loss Value = 4.724127292633057
# Epoch # 1, Time Step # 196, Loss Value = 4.767164707183838
# Epoch # 1, Time Step # 197, Loss Value = 4.630247116088867
# Epoch # 1, Time Step # 198, Loss Value = 4.620391845703125
# Epoch # 1, Time Step # 199, Loss Value = 4.601028919219971
# Epoch # 2, Time Step # 0, Loss Value = 4.506477355957031
# Epoch # 2, Time Step # 1, Loss Value = 4.86309814453125
# Epoch # 2, Time Step # 2, Loss Value = 4.782999038696289
# Epoch # 2, Time Step # 3, Loss Value = 5.24665641784668
# Epoch # 2, Time Step # 4, Loss Value = 5.278882026672363
# Epoch # 2, Time Step # 5, Loss Value = 4.942101955413818
# Epoch # 2, Time Step # 6, Loss Value = 5.2345428466796875
# Epoch # 2, Time Step # 7, Loss Value = 5.068986415863037
# Epoch # 2, Time Step # 8, Loss Value = 5.241846561431885
# Epoch # 2, Time Step # 9, Loss Value = 5.27685546875
# Epoch # 2, Time Step # 10, Loss Value = 4.8346076011657715
# Epoch # 2, Time Step # 11, Loss Value = 5.1843342781066895
# Epoch # 2, Time Step # 12, Loss Value = 4.794719696044922
# Epoch # 2, Time Step # 13, Loss Value = 5.297892093658447
# Epoch # 2, Time Step # 14, Loss Value = 5.130824089050293
# Epoch # 2, Time Step # 15, Loss Value = 5.146207809448242
# Epoch # 2, Time Step # 16, Loss Value = 4.91779899597168
# Epoch # 2, Time Step # 17, Loss Value = 5.051579475402832
# Epoch # 2, Time Step # 18, Loss Value = 4.865468502044678
# Epoch # 2, Time Step # 19, Loss Value = 5.132890701293945
# Epoch # 2, Time Step # 20, Loss Value = 5.0119099617004395
# Epoch # 2, Time Step # 21, Loss Value = 4.839143753051758
# Epoch # 2, Time Step # 22, Loss Value = 4.5682268142700195
# Epoch # 2, Time Step # 23, Loss Value = 4.886366844177246
# Epoch # 2, Time Step # 24, Loss Value = 5.243234634399414
# Epoch # 2, Time Step # 25, Loss Value = 5.01563835144043
# Epoch # 2, Time Step # 26, Loss Value = 4.909549236297607
# Epoch # 2, Time Step # 27, Loss Value = 5.006845951080322
# Epoch # 2, Time Step # 28, Loss Value = 4.778671741485596
# Epoch # 2, Time Step # 29, Loss Value = 4.815454959869385
# Epoch # 2, Time Step # 30, Loss Value = 4.664214611053467
# Epoch # 2, Time Step # 31, Loss Value = 4.645397663116455
# Epoch # 2, Time Step # 32, Loss Value = 4.595935821533203
# Epoch # 2, Time Step # 33, Loss Value = 4.670049667358398
# Epoch # 2, Time Step # 34, Loss Value = 4.994467258453369
# Epoch # 2, Time Step # 35, Loss Value = 5.177694797515869
# Epoch # 2, Time Step # 36, Loss Value = 5.224264621734619
# Epoch # 2, Time Step # 37, Loss Value = 5.126105308532715
# Epoch # 2, Time Step # 38, Loss Value = 5.086577892303467
# Epoch # 2, Time Step # 39, Loss Value = 5.159642696380615
# Epoch # 2, Time Step # 40, Loss Value = 4.910207748413086
# Epoch # 2, Time Step # 41, Loss Value = 4.994158744812012
# Epoch # 2, Time Step # 42, Loss Value = 4.6861701011657715
# Epoch # 2, Time Step # 43, Loss Value = 4.934972286224365
# Epoch # 2, Time Step # 44, Loss Value = 4.6453447341918945
# Epoch # 2, Time Step # 45, Loss Value = 4.6982269287109375
# Epoch # 2, Time Step # 46, Loss Value = 4.988094329833984
# Epoch # 2, Time Step # 47, Loss Value = 4.59498929977417
# Epoch # 2, Time Step # 48, Loss Value = 4.841095447540283
# Epoch # 2, Time Step # 49, Loss Value = 4.726377964019775
# Epoch # 2, Time Step # 50, Loss Value = 4.6450982093811035
# Epoch # 2, Time Step # 51, Loss Value = 4.855113983154297
# Epoch # 2, Time Step # 52, Loss Value = 5.01653528213501
# Epoch # 2, Time Step # 53, Loss Value = 4.834381580352783
# Epoch # 2, Time Step # 54, Loss Value = 5.04236364364624
# Epoch # 2, Time Step # 55, Loss Value = 5.0767741203308105
# Epoch # 2, Time Step # 56, Loss Value = 4.589375972747803
# Epoch # 2, Time Step # 57, Loss Value = 4.8394670486450195
# Epoch # 2, Time Step # 58, Loss Value = 4.825844764709473
# Epoch # 2, Time Step # 59, Loss Value = 4.334551811218262
# Epoch # 2, Time Step # 60, Loss Value = 4.320254325866699
# Epoch # 2, Time Step # 61, Loss Value = 4.524608135223389
# Epoch # 2, Time Step # 62, Loss Value = 5.002845287322998
# Epoch # 2, Time Step # 63, Loss Value = 5.1710124015808105
# Epoch # 2, Time Step # 64, Loss Value = 4.633977890014648
# Epoch # 2, Time Step # 65, Loss Value = 4.909930229187012
# Epoch # 2, Time Step # 66, Loss Value = 5.172412395477295
# Epoch # 2, Time Step # 67, Loss Value = 5.397461891174316
# Epoch # 2, Time Step # 68, Loss Value = 4.830423831939697
# Epoch # 2, Time Step # 69, Loss Value = 5.476974964141846
# Epoch # 2, Time Step # 70, Loss Value = 4.84919548034668
# Epoch # 2, Time Step # 71, Loss Value = 4.801424503326416
# Epoch # 2, Time Step # 72, Loss Value = 4.597970485687256
# Epoch # 2, Time Step # 73, Loss Value = 5.127364635467529
# Epoch # 2, Time Step # 74, Loss Value = 4.928402423858643
# Epoch # 2, Time Step # 75, Loss Value = 4.8651580810546875
# Epoch # 2, Time Step # 76, Loss Value = 4.971415042877197
# Epoch # 2, Time Step # 77, Loss Value = 4.811386585235596
# Epoch # 2, Time Step # 78, Loss Value = 4.419190883636475
# Epoch # 2, Time Step # 79, Loss Value = 4.886704921722412
# Epoch # 2, Time Step # 80, Loss Value = 4.104878902435303
# Epoch # 2, Time Step # 81, Loss Value = 4.658116340637207
# Epoch # 2, Time Step # 82, Loss Value = 4.27817964553833
# Epoch # 2, Time Step # 83, Loss Value = 4.496175765991211
# Epoch # 2, Time Step # 84, Loss Value = 4.25166654586792
# Epoch # 2, Time Step # 85, Loss Value = 4.284011363983154
# Epoch # 2, Time Step # 86, Loss Value = 3.9243533611297607
# Epoch # 2, Time Step # 87, Loss Value = 4.109549522399902
# Epoch # 2, Time Step # 88, Loss Value = 4.2682294845581055
# Epoch # 2, Time Step # 89, Loss Value = 4.142366886138916
# Epoch # 2, Time Step # 90, Loss Value = 3.4232025146484375
# Epoch # 2, Time Step # 91, Loss Value = 3.9262664318084717
# Epoch # 2, Time Step # 92, Loss Value = 4.897050380706787
# Epoch # 2, Time Step # 93, Loss Value = 3.7783267498016357
# Epoch # 2, Time Step # 94, Loss Value = 4.835657119750977
# Epoch # 2, Time Step # 95, Loss Value = 6.017022609710693
# Epoch # 2, Time Step # 96, Loss Value = 6.190871238708496
# Epoch # 2, Time Step # 97, Loss Value = 4.822369575500488
# Epoch # 2, Time Step # 98, Loss Value = 4.159173488616943
# Epoch # 2, Time Step # 99, Loss Value = 4.355898380279541
# Epoch # 2, Time Step # 100, Loss Value = 4.521491050720215
# Epoch # 2, Time Step # 101, Loss Value = 3.798356533050537
# Epoch # 2, Time Step # 102, Loss Value = 3.7155966758728027
# Epoch # 2, Time Step # 103, Loss Value = 4.217247009277344
# Epoch # 2, Time Step # 104, Loss Value = 4.09808874130249
# Epoch # 2, Time Step # 105, Loss Value = 4.141167163848877
# Epoch # 2, Time Step # 106, Loss Value = 4.048940658569336
# Epoch # 2, Time Step # 107, Loss Value = 3.7224082946777344
# Epoch # 2, Time Step # 108, Loss Value = 4.072391510009766
# Epoch # 2, Time Step # 109, Loss Value = 3.8381924629211426
# Epoch # 2, Time Step # 110, Loss Value = 3.927403688430786
# Epoch # 2, Time Step # 111, Loss Value = 5.005942344665527
# Epoch # 2, Time Step # 112, Loss Value = 5.418679237365723
# Epoch # 2, Time Step # 113, Loss Value = 4.916986465454102
# Epoch # 2, Time Step # 114, Loss Value = 4.328053951263428
# Epoch # 2, Time Step # 115, Loss Value = 4.354732990264893
# Epoch # 2, Time Step # 116, Loss Value = 4.529571533203125
# Epoch # 2, Time Step # 117, Loss Value = 4.305567741394043
# Epoch # 2, Time Step # 118, Loss Value = 4.133708953857422
# Epoch # 2, Time Step # 119, Loss Value = 4.551959991455078
# Epoch # 2, Time Step # 120, Loss Value = 4.972654819488525
# Epoch # 2, Time Step # 121, Loss Value = 3.9199907779693604
# Epoch # 2, Time Step # 122, Loss Value = 4.258304595947266
# Epoch # 2, Time Step # 123, Loss Value = 4.238349437713623
# Epoch # 2, Time Step # 124, Loss Value = 4.044072151184082
# Epoch # 2, Time Step # 125, Loss Value = 4.2320685386657715
# Epoch # 2, Time Step # 126, Loss Value = 4.091996669769287
# Epoch # 2, Time Step # 127, Loss Value = 4.246222972869873
# Epoch # 2, Time Step # 128, Loss Value = 4.770752906799316
# Epoch # 2, Time Step # 129, Loss Value = 4.914061546325684
# Epoch # 2, Time Step # 130, Loss Value = 4.864870071411133
# Epoch # 2, Time Step # 131, Loss Value = 4.2651686668396
# Epoch # 2, Time Step # 132, Loss Value = 3.9629008769989014
# Epoch # 2, Time Step # 133, Loss Value = 3.790757656097412
# Epoch # 2, Time Step # 134, Loss Value = 4.23868989944458
# Epoch # 2, Time Step # 135, Loss Value = 3.917076826095581
# Epoch # 2, Time Step # 136, Loss Value = 4.165053844451904
# Epoch # 2, Time Step # 137, Loss Value = 4.270328521728516
# Epoch # 2, Time Step # 138, Loss Value = 3.91922926902771
# Epoch # 2, Time Step # 139, Loss Value = 4.503165245056152
# Epoch # 2, Time Step # 140, Loss Value = 4.234649658203125
# Epoch # 2, Time Step # 141, Loss Value = 4.006921768188477
# Epoch # 2, Time Step # 142, Loss Value = 3.8192245960235596
# Epoch # 2, Time Step # 143, Loss Value = 4.1388983726501465
# Epoch # 2, Time Step # 144, Loss Value = 3.843486785888672
# Epoch # 2, Time Step # 145, Loss Value = 3.7691612243652344
# Epoch # 2, Time Step # 146, Loss Value = 3.6489105224609375
# Epoch # 2, Time Step # 147, Loss Value = 4.224329948425293
# Epoch # 2, Time Step # 148, Loss Value = 4.026470184326172
# Epoch # 2, Time Step # 149, Loss Value = 4.225391864776611
# Epoch # 2, Time Step # 150, Loss Value = 4.042428016662598
# Epoch # 2, Time Step # 151, Loss Value = 4.051137447357178
# Epoch # 2, Time Step # 152, Loss Value = 4.248781681060791
# Epoch # 2, Time Step # 153, Loss Value = 3.952989101409912
# Epoch # 2, Time Step # 154, Loss Value = 3.9241867065429688
# Epoch # 2, Time Step # 155, Loss Value = 4.177007675170898
# Epoch # 2, Time Step # 156, Loss Value = 4.183995246887207
# Epoch # 2, Time Step # 157, Loss Value = 4.1674065589904785
# Epoch # 2, Time Step # 158, Loss Value = 4.121846675872803
# Epoch # 2, Time Step # 159, Loss Value = 5.050651550292969
# Epoch # 2, Time Step # 160, Loss Value = 4.781838893890381
# Epoch # 2, Time Step # 161, Loss Value = 5.015953540802002
# Epoch # 2, Time Step # 162, Loss Value = 4.764652729034424
# Epoch # 2, Time Step # 163, Loss Value = 4.617586135864258
# Epoch # 2, Time Step # 164, Loss Value = 4.6464996337890625
# Epoch # 2, Time Step # 165, Loss Value = 4.347493648529053
# Epoch # 2, Time Step # 166, Loss Value = 4.104893684387207
# Epoch # 2, Time Step # 167, Loss Value = 4.6247429847717285
# Epoch # 2, Time Step # 168, Loss Value = 4.485647678375244
# Epoch # 2, Time Step # 169, Loss Value = 4.449848175048828
# Epoch # 2, Time Step # 170, Loss Value = 4.52567720413208
# Epoch # 2, Time Step # 171, Loss Value = 4.525859832763672
# Epoch # 2, Time Step # 172, Loss Value = 4.956068992614746
# Epoch # 2, Time Step # 173, Loss Value = 4.6503682136535645
# Epoch # 2, Time Step # 174, Loss Value = 4.841616153717041
# Epoch # 2, Time Step # 175, Loss Value = 4.212962627410889
# Epoch # 2, Time Step # 176, Loss Value = 4.168605327606201
# Epoch # 2, Time Step # 177, Loss Value = 4.218653202056885
# Epoch # 2, Time Step # 178, Loss Value = 4.452910423278809
# Epoch # 2, Time Step # 179, Loss Value = 4.269145488739014
# Epoch # 2, Time Step # 180, Loss Value = 4.414342403411865
# Epoch # 2, Time Step # 181, Loss Value = 4.178208351135254
# Epoch # 2, Time Step # 182, Loss Value = 4.005404949188232
# Epoch # 2, Time Step # 183, Loss Value = 4.172767639160156
# Epoch # 2, Time Step # 184, Loss Value = 4.204844951629639
# Epoch # 2, Time Step # 185, Loss Value = 4.048922061920166
# Epoch # 2, Time Step # 186, Loss Value = 4.247037887573242
# Epoch # 2, Time Step # 187, Loss Value = 5.31111478805542
# Epoch # 2, Time Step # 188, Loss Value = 4.197845458984375
# Epoch # 2, Time Step # 189, Loss Value = 4.248835563659668
# Epoch # 2, Time Step # 190, Loss Value = 4.15760612487793
# Epoch # 2, Time Step # 191, Loss Value = 4.2036614418029785
# Epoch # 2, Time Step # 192, Loss Value = 4.270905494689941
# Epoch # 2, Time Step # 193, Loss Value = 3.902709484100342
# Epoch # 2, Time Step # 194, Loss Value = 4.180198669433594
# Epoch # 2, Time Step # 195, Loss Value = 4.5373334884643555
# Epoch # 2, Time Step # 196, Loss Value = 4.513492584228516
# Epoch # 2, Time Step # 197, Loss Value = 4.416575908660889
# Epoch # 2, Time Step # 198, Loss Value = 4.37010383605957
# Epoch # 2, Time Step # 199, Loss Value = 4.394416809082031
# Epoch # 3, Time Step # 0, Loss Value = 4.311365127563477
# Epoch # 3, Time Step # 1, Loss Value = 4.644566535949707
# Epoch # 3, Time Step # 2, Loss Value = 4.564514636993408
# Epoch # 3, Time Step # 3, Loss Value = 5.0419440269470215
# Epoch # 3, Time Step # 4, Loss Value = 5.083005428314209
# Epoch # 3, Time Step # 5, Loss Value = 4.71600866317749
# Epoch # 3, Time Step # 6, Loss Value = 5.050792217254639
# Epoch # 3, Time Step # 7, Loss Value = 4.83922004699707
# Epoch # 3, Time Step # 8, Loss Value = 5.055388927459717
# Epoch # 3, Time Step # 9, Loss Value = 5.094764232635498
# Epoch # 3, Time Step # 10, Loss Value = 4.617001533508301
# Epoch # 3, Time Step # 11, Loss Value = 4.986013412475586
# Epoch # 3, Time Step # 12, Loss Value = 4.600401401519775
# Epoch # 3, Time Step # 13, Loss Value = 5.1004638671875
# Epoch # 3, Time Step # 14, Loss Value = 4.933635234832764
# Epoch # 3, Time Step # 15, Loss Value = 4.958120822906494
# Epoch # 3, Time Step # 16, Loss Value = 4.717292785644531
# Epoch # 3, Time Step # 17, Loss Value = 4.844546318054199
# Epoch # 3, Time Step # 18, Loss Value = 4.687787055969238
# Epoch # 3, Time Step # 19, Loss Value = 4.950937271118164
# Epoch # 3, Time Step # 20, Loss Value = 4.802652835845947
# Epoch # 3, Time Step # 21, Loss Value = 4.650376319885254
# Epoch # 3, Time Step # 22, Loss Value = 4.331971168518066
# Epoch # 3, Time Step # 23, Loss Value = 4.636594772338867
# Epoch # 3, Time Step # 24, Loss Value = 5.044524669647217
# Epoch # 3, Time Step # 25, Loss Value = 4.84499979019165
# Epoch # 3, Time Step # 26, Loss Value = 4.728490829467773
# Epoch # 3, Time Step # 27, Loss Value = 4.796469688415527
# Epoch # 3, Time Step # 28, Loss Value = 4.569640636444092
# Epoch # 3, Time Step # 29, Loss Value = 4.619818210601807
# Epoch # 3, Time Step # 30, Loss Value = 4.464966773986816
# Epoch # 3, Time Step # 31, Loss Value = 4.418950080871582
# Epoch # 3, Time Step # 32, Loss Value = 4.399163722991943
# Epoch # 3, Time Step # 33, Loss Value = 4.464537620544434
# Epoch # 3, Time Step # 34, Loss Value = 4.810050010681152
# Epoch # 3, Time Step # 35, Loss Value = 4.975614070892334
# Epoch # 3, Time Step # 36, Loss Value = 5.044801712036133
# Epoch # 3, Time Step # 37, Loss Value = 4.943278789520264
# Epoch # 3, Time Step # 38, Loss Value = 4.892928123474121
# Epoch # 3, Time Step # 39, Loss Value = 4.988491535186768
# Epoch # 3, Time Step # 40, Loss Value = 4.728529930114746
# Epoch # 3, Time Step # 41, Loss Value = 4.807216644287109
# Epoch # 3, Time Step # 42, Loss Value = 4.520767688751221
# Epoch # 3, Time Step # 43, Loss Value = 4.757723808288574
# Epoch # 3, Time Step # 44, Loss Value = 4.438878059387207
# Epoch # 3, Time Step # 45, Loss Value = 4.501935005187988
# Epoch # 3, Time Step # 46, Loss Value = 4.801697731018066
# Epoch # 3, Time Step # 47, Loss Value = 4.381624221801758
# Epoch # 3, Time Step # 48, Loss Value = 4.6426849365234375
# Epoch # 3, Time Step # 49, Loss Value = 4.546156883239746
# Epoch # 3, Time Step # 50, Loss Value = 4.458049774169922
# Epoch # 3, Time Step # 51, Loss Value = 4.683876991271973
# Epoch # 3, Time Step # 52, Loss Value = 4.833326816558838
# Epoch # 3, Time Step # 53, Loss Value = 4.6378021240234375
# Epoch # 3, Time Step # 54, Loss Value = 4.84793758392334
# Epoch # 3, Time Step # 55, Loss Value = 4.888554096221924
# Epoch # 3, Time Step # 56, Loss Value = 4.387553691864014
# Epoch # 3, Time Step # 57, Loss Value = 4.639897346496582
# Epoch # 3, Time Step # 58, Loss Value = 4.61197566986084
# Epoch # 3, Time Step # 59, Loss Value = 4.1446452140808105
# Epoch # 3, Time Step # 60, Loss Value = 4.093662261962891
# Epoch # 3, Time Step # 61, Loss Value = 4.336759567260742
# Epoch # 3, Time Step # 62, Loss Value = 4.808253288269043
# Epoch # 3, Time Step # 63, Loss Value = 4.972256660461426
# Epoch # 3, Time Step # 64, Loss Value = 4.434635639190674
# Epoch # 3, Time Step # 65, Loss Value = 4.695630073547363
# Epoch # 3, Time Step # 66, Loss Value = 4.9756035804748535
# Epoch # 3, Time Step # 67, Loss Value = 5.226311683654785
# Epoch # 3, Time Step # 68, Loss Value = 4.612524032592773
# Epoch # 3, Time Step # 69, Loss Value = 5.327588081359863
# Epoch # 3, Time Step # 70, Loss Value = 4.632785797119141
# Epoch # 3, Time Step # 71, Loss Value = 4.60284948348999
# Epoch # 3, Time Step # 72, Loss Value = 4.3927202224731445
# Epoch # 3, Time Step # 73, Loss Value = 4.915714740753174
# Epoch # 3, Time Step # 74, Loss Value = 4.712615489959717
# Epoch # 3, Time Step # 75, Loss Value = 4.668079853057861
# Epoch # 3, Time Step # 76, Loss Value = 4.737884044647217
# Epoch # 3, Time Step # 77, Loss Value = 4.58666467666626
# Epoch # 3, Time Step # 78, Loss Value = 4.178587913513184
# Epoch # 3, Time Step # 79, Loss Value = 4.654043197631836
# Epoch # 3, Time Step # 80, Loss Value = 3.871992349624634
# Epoch # 3, Time Step # 81, Loss Value = 4.433465003967285
# Epoch # 3, Time Step # 82, Loss Value = 4.107916355133057
# Epoch # 3, Time Step # 83, Loss Value = 4.285778045654297
# Epoch # 3, Time Step # 84, Loss Value = 4.039247989654541
# Epoch # 3, Time Step # 85, Loss Value = 4.124663352966309
# Epoch # 3, Time Step # 86, Loss Value = 3.7354371547698975
# Epoch # 3, Time Step # 87, Loss Value = 3.9412972927093506
# Epoch # 3, Time Step # 88, Loss Value = 4.097537040710449
# Epoch # 3, Time Step # 89, Loss Value = 3.928546667098999
# Epoch # 3, Time Step # 90, Loss Value = 3.1668598651885986
# Epoch # 3, Time Step # 91, Loss Value = 3.7327322959899902
# Epoch # 3, Time Step # 92, Loss Value = 4.707251071929932
# Epoch # 3, Time Step # 93, Loss Value = 3.587766170501709
# Epoch # 3, Time Step # 94, Loss Value = 4.6508283615112305
# Epoch # 3, Time Step # 95, Loss Value = 5.844820976257324
# Epoch # 3, Time Step # 96, Loss Value = 6.039516448974609
# Epoch # 3, Time Step # 97, Loss Value = 4.610250473022461
# Epoch # 3, Time Step # 98, Loss Value = 3.970750093460083
# Epoch # 3, Time Step # 99, Loss Value = 4.1621413230896
# Epoch # 3, Time Step # 100, Loss Value = 4.341486930847168
# Epoch # 3, Time Step # 101, Loss Value = 3.6115965843200684
# Epoch # 3, Time Step # 102, Loss Value = 3.527360200881958
# Epoch # 3, Time Step # 103, Loss Value = 4.025000095367432
# Epoch # 3, Time Step # 104, Loss Value = 3.877422332763672
# Epoch # 3, Time Step # 105, Loss Value = 3.978304386138916
# Epoch # 3, Time Step # 106, Loss Value = 3.8426637649536133
# Epoch # 3, Time Step # 107, Loss Value = 3.5465049743652344
# Epoch # 3, Time Step # 108, Loss Value = 3.914177894592285
# Epoch # 3, Time Step # 109, Loss Value = 3.6872177124023438
# Epoch # 3, Time Step # 110, Loss Value = 3.743412971496582
# Epoch # 3, Time Step # 111, Loss Value = 4.822368144989014
# Epoch # 3, Time Step # 112, Loss Value = 5.2046427726745605
# Epoch # 3, Time Step # 113, Loss Value = 4.697623252868652
# Epoch # 3, Time Step # 114, Loss Value = 4.103933811187744
# Epoch # 3, Time Step # 115, Loss Value = 4.157074928283691
# Epoch # 3, Time Step # 116, Loss Value = 4.261022090911865
# Epoch # 3, Time Step # 117, Loss Value = 4.115736484527588
# Epoch # 3, Time Step # 118, Loss Value = 3.929715871810913
# Epoch # 3, Time Step # 119, Loss Value = 4.341862201690674
# Epoch # 3, Time Step # 120, Loss Value = 4.733442783355713
# Epoch # 3, Time Step # 121, Loss Value = 3.7028045654296875
# Epoch # 3, Time Step # 122, Loss Value = 4.051844596862793
# Epoch # 3, Time Step # 123, Loss Value = 4.002435684204102
# Epoch # 3, Time Step # 124, Loss Value = 3.8366098403930664
# Epoch # 3, Time Step # 125, Loss Value = 4.039535999298096
# Epoch # 3, Time Step # 126, Loss Value = 3.8674275875091553
# Epoch # 3, Time Step # 127, Loss Value = 4.013537406921387
# Epoch # 3, Time Step # 128, Loss Value = 4.578256130218506
# Epoch # 3, Time Step # 129, Loss Value = 4.713640213012695
# Epoch # 3, Time Step # 130, Loss Value = 4.673279762268066
# Epoch # 3, Time Step # 131, Loss Value = 4.051032066345215
# Epoch # 3, Time Step # 132, Loss Value = 3.7805707454681396
# Epoch # 3, Time Step # 133, Loss Value = 3.6447885036468506
# Epoch # 3, Time Step # 134, Loss Value = 4.0377302169799805
# Epoch # 3, Time Step # 135, Loss Value = 3.701622486114502
# Epoch # 3, Time Step # 136, Loss Value = 3.934546947479248
# Epoch # 3, Time Step # 137, Loss Value = 4.045936107635498
# Epoch # 3, Time Step # 138, Loss Value = 3.733776807785034
# Epoch # 3, Time Step # 139, Loss Value = 4.288773536682129
# Epoch # 3, Time Step # 140, Loss Value = 4.017691135406494
# Epoch # 3, Time Step # 141, Loss Value = 3.818401575088501
# Epoch # 3, Time Step # 142, Loss Value = 3.625232458114624
# Epoch # 3, Time Step # 143, Loss Value = 3.922335386276245
# Epoch # 3, Time Step # 144, Loss Value = 3.6399319171905518
# Epoch # 3, Time Step # 145, Loss Value = 3.552238702774048
# Epoch # 3, Time Step # 146, Loss Value = 3.40462327003479
# Epoch # 3, Time Step # 147, Loss Value = 4.029686450958252
# Epoch # 3, Time Step # 148, Loss Value = 3.834052562713623
# Epoch # 3, Time Step # 149, Loss Value = 4.012501239776611
# Epoch # 3, Time Step # 150, Loss Value = 3.820030927658081
# Epoch # 3, Time Step # 151, Loss Value = 3.81071400642395
# Epoch # 3, Time Step # 152, Loss Value = 4.016814231872559
# Epoch # 3, Time Step # 153, Loss Value = 3.7484498023986816
# Epoch # 3, Time Step # 154, Loss Value = 3.731287956237793
# Epoch # 3, Time Step # 155, Loss Value = 4.000280380249023
# Epoch # 3, Time Step # 156, Loss Value = 3.977450370788574
# Epoch # 3, Time Step # 157, Loss Value = 3.977753162384033
# Epoch # 3, Time Step # 158, Loss Value = 3.9256179332733154
# Epoch # 3, Time Step # 159, Loss Value = 4.827681541442871
# Epoch # 3, Time Step # 160, Loss Value = 4.600365161895752
# Epoch # 3, Time Step # 161, Loss Value = 4.8006696701049805
# Epoch # 3, Time Step # 162, Loss Value = 4.5071797370910645
# Epoch # 3, Time Step # 163, Loss Value = 4.435250282287598
# Epoch # 3, Time Step # 164, Loss Value = 4.428398609161377
# Epoch # 3, Time Step # 165, Loss Value = 4.134742259979248
# Epoch # 3, Time Step # 166, Loss Value = 3.8997092247009277
# Epoch # 3, Time Step # 167, Loss Value = 4.4363112449646
# Epoch # 3, Time Step # 168, Loss Value = 4.328866958618164
# Epoch # 3, Time Step # 169, Loss Value = 4.247923374176025
# Epoch # 3, Time Step # 170, Loss Value = 4.334522247314453
# Epoch # 3, Time Step # 171, Loss Value = 4.313334941864014
# Epoch # 3, Time Step # 172, Loss Value = 4.758683204650879
# Epoch # 3, Time Step # 173, Loss Value = 4.430551052093506
# Epoch # 3, Time Step # 174, Loss Value = 4.65308141708374
# Epoch # 3, Time Step # 175, Loss Value = 3.9902162551879883
# Epoch # 3, Time Step # 176, Loss Value = 3.9694178104400635
# Epoch # 3, Time Step # 177, Loss Value = 4.013645648956299
# Epoch # 3, Time Step # 178, Loss Value = 4.2100701332092285
# Epoch # 3, Time Step # 179, Loss Value = 4.066223621368408
# Epoch # 3, Time Step # 180, Loss Value = 4.160010814666748
# Epoch # 3, Time Step # 181, Loss Value = 3.952610969543457
# Epoch # 3, Time Step # 182, Loss Value = 3.790593147277832
# Epoch # 3, Time Step # 183, Loss Value = 3.9978280067443848
# Epoch # 3, Time Step # 184, Loss Value = 4.01723575592041
# Epoch # 3, Time Step # 185, Loss Value = 3.8320798873901367
# Epoch # 3, Time Step # 186, Loss Value = 4.0453691482543945
# Epoch # 3, Time Step # 187, Loss Value = 5.058437824249268
# Epoch # 3, Time Step # 188, Loss Value = 4.0084404945373535
# Epoch # 3, Time Step # 189, Loss Value = 4.055936336517334
# Epoch # 3, Time Step # 190, Loss Value = 3.955470085144043
# Epoch # 3, Time Step # 191, Loss Value = 4.0052337646484375
# Epoch # 3, Time Step # 192, Loss Value = 4.036726474761963
# Epoch # 3, Time Step # 193, Loss Value = 3.7091939449310303
# Epoch # 3, Time Step # 194, Loss Value = 3.976416826248169
# Epoch # 3, Time Step # 195, Loss Value = 4.371424674987793
# Epoch # 3, Time Step # 196, Loss Value = 4.3162841796875
# Epoch # 3, Time Step # 197, Loss Value = 4.249845027923584
# Epoch # 3, Time Step # 198, Loss Value = 4.1820902824401855
# Epoch # 3, Time Step # 199, Loss Value = 4.223811626434326
# Epoch # 4, Time Step # 0, Loss Value = 4.143650531768799
# Epoch # 4, Time Step # 1, Loss Value = 4.459716320037842
# Epoch # 4, Time Step # 2, Loss Value = 4.380512714385986
# Epoch # 4, Time Step # 3, Loss Value = 4.8524250984191895
# Epoch # 4, Time Step # 4, Loss Value = 4.913476467132568
# Epoch # 4, Time Step # 5, Loss Value = 4.5108642578125
# Epoch # 4, Time Step # 6, Loss Value = 4.8852057456970215
# Epoch # 4, Time Step # 7, Loss Value = 4.65127420425415
# Epoch # 4, Time Step # 8, Loss Value = 4.888894081115723
# Epoch # 4, Time Step # 9, Loss Value = 4.929029941558838
# Epoch # 4, Time Step # 10, Loss Value = 4.439676284790039
# Epoch # 4, Time Step # 11, Loss Value = 4.813323020935059
# Epoch # 4, Time Step # 12, Loss Value = 4.430849552154541
# Epoch # 4, Time Step # 13, Loss Value = 4.920161247253418
# Epoch # 4, Time Step # 14, Loss Value = 4.754553318023682
# Epoch # 4, Time Step # 15, Loss Value = 4.792478561401367
# Epoch # 4, Time Step # 16, Loss Value = 4.539662837982178
# Epoch # 4, Time Step # 17, Loss Value = 4.655134201049805
# Epoch # 4, Time Step # 18, Loss Value = 4.529687881469727
# Epoch # 4, Time Step # 19, Loss Value = 4.7853007316589355
# Epoch # 4, Time Step # 20, Loss Value = 4.613682746887207
# ...
# Epoch # 298, Time Step # 145, Loss Value = 0.09059000015258789
# Epoch # 298, Time Step # 146, Loss Value = 0.23251113295555115
# Epoch # 298, Time Step # 147, Loss Value = 0.2122677117586136
# Epoch # 298, Time Step # 148, Loss Value = 0.09744461625814438
# Epoch # 298, Time Step # 149, Loss Value = 0.06417161971330643
# Epoch # 298, Time Step # 150, Loss Value = 0.09597859531641006
# Epoch # 298, Time Step # 151, Loss Value = 0.09840619564056396
# Epoch # 298, Time Step # 152, Loss Value = 0.11223035305738449
# Epoch # 298, Time Step # 153, Loss Value = 0.17240701615810394
# Epoch # 298, Time Step # 154, Loss Value = 0.10447168350219727
# Epoch # 298, Time Step # 155, Loss Value = 0.04319417476654053
# Epoch # 298, Time Step # 156, Loss Value = 0.1484132707118988
# Epoch # 298, Time Step # 157, Loss Value = 0.1257888525724411
# Epoch # 298, Time Step # 158, Loss Value = 0.07248394936323166
# Epoch # 298, Time Step # 159, Loss Value = 0.023359602317214012
# Epoch # 298, Time Step # 160, Loss Value = 0.04487044736742973
# Epoch # 298, Time Step # 161, Loss Value = 0.09777010232210159
# Epoch # 298, Time Step # 162, Loss Value = 0.08197981119155884
# Epoch # 298, Time Step # 163, Loss Value = 0.1299397349357605
# Epoch # 298, Time Step # 164, Loss Value = 0.2606950104236603
# Epoch # 298, Time Step # 165, Loss Value = 0.06671508401632309
# Epoch # 298, Time Step # 166, Loss Value = 0.08314242213964462
# Epoch # 298, Time Step # 167, Loss Value = 0.08721120655536652
# Epoch # 298, Time Step # 168, Loss Value = 0.02510197088122368
# Epoch # 298, Time Step # 169, Loss Value = 0.07104116678237915
# Epoch # 298, Time Step # 170, Loss Value = 0.0631023719906807
# Epoch # 298, Time Step # 171, Loss Value = 0.07671307027339935
# Epoch # 298, Time Step # 172, Loss Value = 0.026863981038331985
# Epoch # 298, Time Step # 173, Loss Value = 0.03434992581605911
# Epoch # 298, Time Step # 174, Loss Value = 0.039876263588666916
# Epoch # 298, Time Step # 175, Loss Value = 0.07172204554080963
# Epoch # 298, Time Step # 176, Loss Value = 0.10002928972244263
# Epoch # 298, Time Step # 177, Loss Value = 0.07235073298215866
# Epoch # 298, Time Step # 178, Loss Value = 0.0811973363161087
# Epoch # 298, Time Step # 179, Loss Value = 0.05243053287267685
# Epoch # 298, Time Step # 180, Loss Value = 0.05838750675320625
# Epoch # 298, Time Step # 181, Loss Value = 0.10233616083860397
# Epoch # 298, Time Step # 182, Loss Value = 0.11447688937187195
# Epoch # 298, Time Step # 183, Loss Value = 0.0842958614230156
# Epoch # 298, Time Step # 184, Loss Value = 0.08980952203273773
# Epoch # 298, Time Step # 185, Loss Value = 0.10229538381099701
# Epoch # 298, Time Step # 186, Loss Value = 0.09399423748254776
# Epoch # 298, Time Step # 187, Loss Value = 0.04633823782205582
# Epoch # 298, Time Step # 188, Loss Value = 0.09094623476266861
# Epoch # 298, Time Step # 189, Loss Value = 0.08853897452354431
# Epoch # 298, Time Step # 190, Loss Value = 0.12167973071336746
# Epoch # 298, Time Step # 191, Loss Value = 0.09330543130636215
# Epoch # 298, Time Step # 192, Loss Value = 0.10652251541614532
# Epoch # 298, Time Step # 193, Loss Value = 0.07838194072246552
# Epoch # 298, Time Step # 194, Loss Value = 0.10999593883752823
# Epoch # 298, Time Step # 195, Loss Value = 0.07620880007743835
# Epoch # 298, Time Step # 196, Loss Value = 0.03199468553066254
# Epoch # 298, Time Step # 197, Loss Value = 0.04436713084578514
# Epoch # 298, Time Step # 198, Loss Value = 0.08385740220546722
# Epoch # 298, Time Step # 199, Loss Value = 0.025668801739811897
# Epoch # 299, Time Step # 0, Loss Value = 0.09002037346363068
# Epoch # 299, Time Step # 1, Loss Value = 0.03454937785863876
# Epoch # 299, Time Step # 2, Loss Value = 0.07456991821527481
# Epoch # 299, Time Step # 3, Loss Value = 0.035149771720170975
# Epoch # 299, Time Step # 4, Loss Value = 0.035265807062387466
# Epoch # 299, Time Step # 5, Loss Value = 0.050803445279598236
# Epoch # 299, Time Step # 6, Loss Value = 0.02820410020649433
# Epoch # 299, Time Step # 7, Loss Value = 0.0319194495677948
# Epoch # 299, Time Step # 8, Loss Value = 0.04722284525632858
# Epoch # 299, Time Step # 9, Loss Value = 0.05778801813721657
# Epoch # 299, Time Step # 10, Loss Value = 0.05638255551457405
# Epoch # 299, Time Step # 11, Loss Value = 0.03388077765703201
# Epoch # 299, Time Step # 12, Loss Value = 0.04199178144335747
# Epoch # 299, Time Step # 13, Loss Value = 0.020701415836811066
# Epoch # 299, Time Step # 14, Loss Value = 0.029987720772624016
# Epoch # 299, Time Step # 15, Loss Value = 0.021790985018014908
# Epoch # 299, Time Step # 16, Loss Value = 0.03193914517760277
# Epoch # 299, Time Step # 17, Loss Value = 0.030815962702035904
# Epoch # 299, Time Step # 18, Loss Value = 0.031231457367539406
# Epoch # 299, Time Step # 19, Loss Value = 0.03251145780086517
# Epoch # 299, Time Step # 20, Loss Value = 0.040823545306921005
# Epoch # 299, Time Step # 21, Loss Value = 0.03985485062003136
# Epoch # 299, Time Step # 22, Loss Value = 0.07893450558185577
# Epoch # 299, Time Step # 23, Loss Value = 0.08228275179862976
# Epoch # 299, Time Step # 24, Loss Value = 0.03683490306138992
# Epoch # 299, Time Step # 25, Loss Value = 0.05065075308084488
# Epoch # 299, Time Step # 26, Loss Value = 0.03767934441566467
# Epoch # 299, Time Step # 27, Loss Value = 0.03790735453367233
# Epoch # 299, Time Step # 28, Loss Value = 0.02270803414285183
# Epoch # 299, Time Step # 29, Loss Value = 0.032883595675230026
# Epoch # 299, Time Step # 30, Loss Value = 0.025818925350904465
# Epoch # 299, Time Step # 31, Loss Value = 0.04970403388142586
# Epoch # 299, Time Step # 32, Loss Value = 0.027642052620649338
# Epoch # 299, Time Step # 33, Loss Value = 0.034289296716451645
# Epoch # 299, Time Step # 34, Loss Value = 0.04729640111327171
# Epoch # 299, Time Step # 35, Loss Value = 0.03409162908792496
# Epoch # 299, Time Step # 36, Loss Value = 0.03448724001646042
# Epoch # 299, Time Step # 37, Loss Value = 0.044368937611579895
# Epoch # 299, Time Step # 38, Loss Value = 0.05740885064005852
# Epoch # 299, Time Step # 39, Loss Value = 0.028139552101492882
# Epoch # 299, Time Step # 40, Loss Value = 0.03422053903341293
# Epoch # 299, Time Step # 41, Loss Value = 0.06953608989715576
# Epoch # 299, Time Step # 42, Loss Value = 0.04098613187670708
# Epoch # 299, Time Step # 43, Loss Value = 0.032790657132864
# Epoch # 299, Time Step # 44, Loss Value = 0.046890873461961746
# Epoch # 299, Time Step # 45, Loss Value = 0.043419335037469864
# Epoch # 299, Time Step # 46, Loss Value = 0.02263583615422249
# Epoch # 299, Time Step # 47, Loss Value = 0.04840034618973732
# Epoch # 299, Time Step # 48, Loss Value = 0.03249765560030937
# Epoch # 299, Time Step # 49, Loss Value = 0.03998304158449173
# Epoch # 299, Time Step # 50, Loss Value = 0.03881889581680298
# Epoch # 299, Time Step # 51, Loss Value = 0.03824800252914429
# Epoch # 299, Time Step # 52, Loss Value = 0.037678975611925125
# Epoch # 299, Time Step # 53, Loss Value = 0.04736192896962166
# Epoch # 299, Time Step # 54, Loss Value = 0.045077160000801086
# Epoch # 299, Time Step # 55, Loss Value = 0.08208166807889938
# Epoch # 299, Time Step # 56, Loss Value = 0.038710180670022964
# Epoch # 299, Time Step # 57, Loss Value = 0.03986511006951332
# Epoch # 299, Time Step # 58, Loss Value = 0.02756735309958458
# Epoch # 299, Time Step # 59, Loss Value = 0.03891158103942871
# Epoch # 299, Time Step # 60, Loss Value = 0.10408873856067657
# Epoch # 299, Time Step # 61, Loss Value = 0.04786255583167076
# Epoch # 299, Time Step # 62, Loss Value = 0.029431674629449844
# Epoch # 299, Time Step # 63, Loss Value = 0.03199399635195732
# Epoch # 299, Time Step # 64, Loss Value = 0.04305902123451233
# Epoch # 299, Time Step # 65, Loss Value = 0.05679118260741234
# Epoch # 299, Time Step # 66, Loss Value = 0.04543608799576759
# Epoch # 299, Time Step # 67, Loss Value = 0.027022039517760277
# Epoch # 299, Time Step # 68, Loss Value = 0.06868452578783035
# Epoch # 299, Time Step # 69, Loss Value = 0.049301374703645706
# Epoch # 299, Time Step # 70, Loss Value = 0.06962627172470093
# Epoch # 299, Time Step # 71, Loss Value = 0.0893562063574791
# Epoch # 299, Time Step # 72, Loss Value = 0.10828734189271927
# Epoch # 299, Time Step # 73, Loss Value = 0.06658054888248444
# Epoch # 299, Time Step # 74, Loss Value = 0.06282917410135269
# Epoch # 299, Time Step # 75, Loss Value = 0.06690973788499832
# Epoch # 299, Time Step # 76, Loss Value = 0.0962434709072113
# Epoch # 299, Time Step # 77, Loss Value = 0.07036566734313965
# Epoch # 299, Time Step # 78, Loss Value = 0.09026523679494858
# Epoch # 299, Time Step # 79, Loss Value = 0.0480274073779583
# Epoch # 299, Time Step # 80, Loss Value = 0.14406555891036987
# Epoch # 299, Time Step # 81, Loss Value = 0.0898265689611435
# Epoch # 299, Time Step # 82, Loss Value = 0.07330100983381271
# Epoch # 299, Time Step # 83, Loss Value = 0.1032235398888588
# Epoch # 299, Time Step # 84, Loss Value = 0.09457873553037643
# Epoch # 299, Time Step # 85, Loss Value = 0.09510306268930435
# Epoch # 299, Time Step # 86, Loss Value = 0.06756921857595444
# Epoch # 299, Time Step # 87, Loss Value = 0.09306703507900238
# Epoch # 299, Time Step # 88, Loss Value = 0.05802131071686745
# Epoch # 299, Time Step # 89, Loss Value = 0.08841702342033386
# Epoch # 299, Time Step # 90, Loss Value = 0.0853838101029396
# Epoch # 299, Time Step # 91, Loss Value = 0.13865117728710175
# Epoch # 299, Time Step # 92, Loss Value = 0.07570117712020874
# Epoch # 299, Time Step # 93, Loss Value = 0.0892714187502861
# Epoch # 299, Time Step # 94, Loss Value = 0.04502132907509804
# Epoch # 299, Time Step # 95, Loss Value = 0.017254751175642014
# Epoch # 299, Time Step # 96, Loss Value = 0.04872020334005356
# Epoch # 299, Time Step # 97, Loss Value = 0.046293970197439194
# Epoch # 299, Time Step # 98, Loss Value = 0.07592332363128662
# Epoch # 299, Time Step # 99, Loss Value = 0.05044073238968849
# Epoch # 299, Time Step # 100, Loss Value = 0.042196717113256454
# Epoch # 299, Time Step # 101, Loss Value = 0.06967277079820633
# Epoch # 299, Time Step # 102, Loss Value = 0.06976363062858582
# Epoch # 299, Time Step # 103, Loss Value = 0.1019129604101181
# Epoch # 299, Time Step # 104, Loss Value = 0.09512559324502945
# Epoch # 299, Time Step # 105, Loss Value = 0.09027908742427826
# Epoch # 299, Time Step # 106, Loss Value = 0.12013658136129379
# Epoch # 299, Time Step # 107, Loss Value = 0.07682531327009201
# Epoch # 299, Time Step # 108, Loss Value = 0.04218820855021477
# Epoch # 299, Time Step # 109, Loss Value = 0.022801730781793594
# Epoch # 299, Time Step # 110, Loss Value = 0.0629471093416214
# Epoch # 299, Time Step # 111, Loss Value = 0.029091309756040573
# Epoch # 299, Time Step # 112, Loss Value = 0.03205043449997902
# Epoch # 299, Time Step # 113, Loss Value = 0.04462879151105881
# Epoch # 299, Time Step # 114, Loss Value = 0.08499645441770554
# Epoch # 299, Time Step # 115, Loss Value = 0.08519437164068222
# Epoch # 299, Time Step # 116, Loss Value = 0.09852643311023712
# Epoch # 299, Time Step # 117, Loss Value = 0.08209863305091858
# Epoch # 299, Time Step # 118, Loss Value = 0.07978622615337372
# Epoch # 299, Time Step # 119, Loss Value = 0.04673870652914047
# Epoch # 299, Time Step # 120, Loss Value = 0.07225050777196884
# Epoch # 299, Time Step # 121, Loss Value = 0.0854450911283493
# Epoch # 299, Time Step # 122, Loss Value = 0.1034851223230362
# Epoch # 299, Time Step # 123, Loss Value = 0.06392171233892441
# Epoch # 299, Time Step # 124, Loss Value = 0.08762030303478241
# Epoch # 299, Time Step # 125, Loss Value = 0.05596356466412544
# Epoch # 299, Time Step # 126, Loss Value = 0.06441964954137802
# Epoch # 299, Time Step # 127, Loss Value = 0.10832909494638443
# Epoch # 299, Time Step # 128, Loss Value = 0.035948898643255234
# Epoch # 299, Time Step # 129, Loss Value = 0.029677394777536392
# Epoch # 299, Time Step # 130, Loss Value = 0.03044624626636505
# Epoch # 299, Time Step # 131, Loss Value = 0.05748673528432846
# Epoch # 299, Time Step # 132, Loss Value = 0.09093015640974045
# Epoch # 299, Time Step # 133, Loss Value = 0.13435550034046173
# Epoch # 299, Time Step # 134, Loss Value = 0.09165239334106445
# Epoch # 299, Time Step # 135, Loss Value = 0.13714544475078583
# Epoch # 299, Time Step # 136, Loss Value = 0.12754100561141968
# Epoch # 299, Time Step # 137, Loss Value = 0.17245596647262573
# Epoch # 299, Time Step # 138, Loss Value = 0.1373009979724884
# Epoch # 299, Time Step # 139, Loss Value = 0.08928237855434418
# Epoch # 299, Time Step # 140, Loss Value = 0.10865668952465057
# Epoch # 299, Time Step # 141, Loss Value = 0.08047836273908615
# Epoch # 299, Time Step # 142, Loss Value = 0.089082270860672
# Epoch # 299, Time Step # 143, Loss Value = 0.10557840019464493
# Epoch # 299, Time Step # 144, Loss Value = 0.16170668601989746
# Epoch # 299, Time Step # 145, Loss Value = 0.08529283851385117
# Epoch # 299, Time Step # 146, Loss Value = 0.2683757245540619
# Epoch # 299, Time Step # 147, Loss Value = 0.21705417335033417
# Epoch # 299, Time Step # 148, Loss Value = 0.100811667740345
# Epoch # 299, Time Step # 149, Loss Value = 0.06432478129863739
# Epoch # 299, Time Step # 150, Loss Value = 0.10233882069587708
# Epoch # 299, Time Step # 151, Loss Value = 0.09885631501674652
# Epoch # 299, Time Step # 152, Loss Value = 0.11664240807294846
# Epoch # 299, Time Step # 153, Loss Value = 0.16865701973438263
# Epoch # 299, Time Step # 154, Loss Value = 0.10342057049274445
# Epoch # 299, Time Step # 155, Loss Value = 0.0428481251001358
# Epoch # 299, Time Step # 156, Loss Value = 0.15613871812820435
# Epoch # 299, Time Step # 157, Loss Value = 0.12164001166820526
# Epoch # 299, Time Step # 158, Loss Value = 0.07424800843000412
# Epoch # 299, Time Step # 159, Loss Value = 0.02818813920021057
# Epoch # 299, Time Step # 160, Loss Value = 0.07386661320924759
# Epoch # 299, Time Step # 161, Loss Value = 0.10067984461784363
# Epoch # 299, Time Step # 162, Loss Value = 0.0784866213798523
# Epoch # 299, Time Step # 163, Loss Value = 0.13155485689640045
# Epoch # 299, Time Step # 164, Loss Value = 0.2531079649925232
# Epoch # 299, Time Step # 165, Loss Value = 0.06321446597576141
# Epoch # 299, Time Step # 166, Loss Value = 0.08293448388576508
# Epoch # 299, Time Step # 167, Loss Value = 0.08796398341655731
# Epoch # 299, Time Step # 168, Loss Value = 0.027743499726057053
# Epoch # 299, Time Step # 169, Loss Value = 0.07165882736444473
# Epoch # 299, Time Step # 170, Loss Value = 0.06591809540987015
# Epoch # 299, Time Step # 171, Loss Value = 0.06922492384910583
# Epoch # 299, Time Step # 172, Loss Value = 0.02736041508615017
# Epoch # 299, Time Step # 173, Loss Value = 0.03628301993012428
# Epoch # 299, Time Step # 174, Loss Value = 0.04266279190778732
# Epoch # 299, Time Step # 175, Loss Value = 0.07565899193286896
# Epoch # 299, Time Step # 176, Loss Value = 0.0788693055510521
# Epoch # 299, Time Step # 177, Loss Value = 0.07212508469820023
# Epoch # 299, Time Step # 178, Loss Value = 0.08314599841833115
# Epoch # 299, Time Step # 179, Loss Value = 0.04776425287127495
# Epoch # 299, Time Step # 180, Loss Value = 0.06152937188744545
# Epoch # 299, Time Step # 181, Loss Value = 0.11825530976057053
# Epoch # 299, Time Step # 182, Loss Value = 0.11467764526605606
# Epoch # 299, Time Step # 183, Loss Value = 0.09089948236942291
# Epoch # 299, Time Step # 184, Loss Value = 0.08536332845687866
# Epoch # 299, Time Step # 185, Loss Value = 0.10334745049476624
# Epoch # 299, Time Step # 186, Loss Value = 0.09560324996709824
# Epoch # 299, Time Step # 187, Loss Value = 0.04827667027711868
# Epoch # 299, Time Step # 188, Loss Value = 0.09433341026306152
# Epoch # 299, Time Step # 189, Loss Value = 0.07443228363990784
# Epoch # 299, Time Step # 190, Loss Value = 0.1322084218263626
# Epoch # 299, Time Step # 191, Loss Value = 0.08978559076786041
# Epoch # 299, Time Step # 192, Loss Value = 0.10573049634695053
# Epoch # 299, Time Step # 193, Loss Value = 0.07913114130496979
# Epoch # 299, Time Step # 194, Loss Value = 0.10331349819898605
# Epoch # 299, Time Step # 195, Loss Value = 0.06815830618143082
# Epoch # 299, Time Step # 196, Loss Value = 0.029632706195116043
# Epoch # 299, Time Step # 197, Loss Value = 0.045665204524993896
# Epoch # 299, Time Step # 198, Loss Value = 0.08193248510360718
# Epoch # 299, Time Step # 199, Loss Value = 0.031324125826358795

# %%
torch.save(network.state_dict(),"model.pth")

# %%
def generate_translation(eng_sentence):

    tokenized_eng_sentence = src_sent_tokenizer.tokenize(eng_sentence)
    token_ids = src_sent_tokenizer.convert_tokens_to_ids(tokenized_eng_sentence)
    token_ids_tensor = torch.tensor(token_ids)
    token_ids_tensor = torch.unsqueeze(token_ids_tensor,0)

    if torch.cuda.is_available():
        device = torch.device("cuda")
        token_ids_tensor = token_ids_tensor.to(device)

    encoder_outputs,(final_encoder_output,final_candidate_cell_state) = network.encoder(token_ids_tensor)
    decoder_first_time_step_input = torch.tensor([[1]])

    if torch.cuda.is_available():
        encoder_outputs = encoder_outputs.to(device)
        final_encoder_output = final_encoder_output.to(device)
        final_candidate_cell_state = final_candidate_cell_state.to(device)
        decoder_first_time_step_input = decoder_first_time_step_input.to(device)

    decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(decoder_first_time_step_input,
                                                                          final_encoder_output,
                                                                          final_candidate_cell_state)

    generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
    generated_token_id = torch.unsqueeze(generated_token_id,1)

    hindi_translated_sentence = str()
    hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    if torch.cuda.is_available():
        generated_token_id = generated_token_id.to(device)
        hidden_decoder_output = hidden_decoder_output.to(device)
        hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)
        
    for i in range(nd-1):
        
        decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(generated_token_id,
                                                                                                hidden_decoder_output,
                                                                                                hidden_decoder_cell_state)
        generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
        generated_token_id = torch.unsqueeze(generated_token_id,1)

        if torch.cuda.is_available():
            generated_token_id = generated_token_id.to(device)
            hidden_decoder_output = hidden_decoder_output.to(device)
            hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)

        if generated_token_id.item() == vd["<EOS>"]:
            break

        hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    return hindi_translated_sentence

# %%
print(generate_translation("Muiriel"))
# Out:
#  अभी में लानत है ।
